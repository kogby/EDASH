# %%
import pandas as pd

# %%
row_count = 0
df = pd.read_csv('./data/Gas Sensor Drift Dataset/batch1.dat', delimiter=' ', header=None)
for i in range(2,11):
    df2 = pd.read_csv(f'./data/Gas Sensor Drift Dataset/batch{i}.dat',delimiter=' ', header=None)
    df = pd.concat([df, df2], axis=0, ignore_index=True)

# split label
df[['Gas Class', 'Gas Num']] = df[0].str.split(';', expand=True).astype('float')

# clean each feature
for i in df.columns:
    if i in ['Gas Class', 'Gas Num', 129,0]:
        continue
    else:
        df[i] = df[i].str.split(':').str.get(1).astype('float')
        df = df.rename(columns={i: f'feat_{i}'})

# drop empty column
df.drop([0,129], axis=1, inplace=True)

# transform label into name
replace_mapping = {
    1.0 : '1',
    2.0 : '2',
    3.0 : '3',
    4.0 : '4',
    5.0 : '5',
    6.0 : '6',
}
df['Gas Class'].replace(replace_mapping, inplace=True)
display(df)
# Out:
#             feat_1     feat_2     feat_3     feat_4      feat_5     feat_6  \
# 0       15596.1621   1.868245   2.371604   2.803678    7.512213  -2.739388
# 1       26402.0704   2.532401   5.411209   6.509906    7.658469  -4.722217
# 2       42103.5820   3.454189   8.198175  10.508439   11.611003  -7.668313
# 3       42825.9883   3.451192  12.113940  16.266853   39.910056  -7.849409
# 4       58151.1757   4.194839  11.455096  15.715298   17.654915 -11.083364
# ...            ...        ...        ...        ...         ...        ...
# 13905   28929.5108   3.309200   4.393300   5.057000    9.423300  -3.879400
# 13906   40392.1230   3.280000  10.268900  13.585900   20.979000  -8.173200
# 13907  183271.5898  15.594500  45.480300  63.877500   81.139600 -29.539100
# 13908   29059.8516   2.568000   6.714200   8.786500   13.987800  -6.041100
# 13909  230762.7607  19.166600  60.936400  87.855700  117.341400 -36.421000
#
#           feat_7      feat_8       feat_9    feat_10  ...    feat_121  \
# 0      -3.344671   -4.847512   15326.6914   1.768526  ...   3037.0390
# 1      -5.817651   -7.518333   23855.7812   2.164706  ...   4176.4453
# 2      -9.478675  -12.230939   37562.3008   2.840403  ...   5914.6685
# 3      -9.689894  -11.921704   38379.0664   2.851173  ...   6147.4744
# 4     -13.580692  -16.407848   51975.5899   3.480866  ...   8158.6449
# ...          ...         ...          ...        ...  ...         ...
# 13905  -5.415100  -15.933500   42203.8965   3.377800  ...   5480.6582
# 13906 -10.859100  -31.802700   40322.3164   2.594000  ...  15700.0969
# 13907 -47.626600 -329.266900  229854.3418  14.519400  ...  50936.2070
# 13908  -8.070700  -22.322300   28441.1289   2.069400  ...  10079.5098
# 13909 -69.145400 -630.869600  287258.4492  17.268800  ...  86175.8168
#
#         feat_122   feat_123   feat_124   feat_125   feat_126   feat_127  \
# 0       3.972203   0.527291   0.728443   1.445783  -0.545079  -0.902241
# 1       4.281373   0.980205   1.628050   1.951172  -0.889333  -1.323505
# 2       5.396827   1.403973   2.476956   3.039841  -1.334558  -1.993659
# 3       5.501071   1.981933   3.569823   4.049197  -1.432205  -2.146158
# 4       7.174334   1.993808   3.829303   4.402448  -1.930107  -2.931265
# ...          ...        ...        ...        ...        ...        ...
# 13905   2.851000   1.046500   2.039900   5.341900  -0.842830  -1.407700
# 13906   5.216200   5.167500   8.995000  11.591700  -4.495400  -7.655300
# 13907  17.808000  17.288700  26.789500  33.366100 -15.823700 -28.516200
# 13908   3.539900   3.266000   6.249900   9.026200  -2.849500  -4.734300
# 13909  29.413100  29.831000  49.226900  60.609800 -28.627700 -54.254800
#
#          feat_128  Gas Class  Gas Num
# 0       -2.654529          1     10.0
# 1       -1.749225          1     20.0
# 2       -2.348370          1     30.0
# 3       -2.488957          1     40.0
# 4       -4.088756          1     50.0
# ...           ...        ...      ...
# 13905   -4.447900          5     50.0
# 13906  -12.767100          4    250.0
# 13907  -56.332800          5    600.0
# 13908   -9.573100          4    150.0
# 13909 -125.588800          5   1000.0
#
# [13910 rows x 130 columns]

# %%
# Check whether each class has correct amounts of data.
print(df['Gas Class'].value_counts())
df.to_csv('./data/gas_sensor_drift_training_data.csv', index=False)
# Out:
# Gas Class
# 5    3009
# 2    2926
# 1    2565
# 4    1936
# 6    1833
# 3    1641
# Name: count, dtype: int64

# %%
# grouped_df = df[['Gas Class','Gas Num']].groupby('Gas Class')
# display(grouped_df.max())
# display(grouped_df.min())
# display(df[df['Gas Num']==600][df['Gas Class']==1])
# display(df['Gas Num'][650:700])

# no nan values
print(df.isna().sum().sum())
# Out:
# 0
